# %%
from flask import Flask, request, render_template
import pickle
import numpy as np

# %%
app = Flask(__name__)

@app.route('/')
def home():
	return render_template('home.html')
@app.route('/getcause',methods=['POST','GET'])
def get_cause():
    if request.method=='POST':
        result=request.form
        
        méthode = result['méthode']
        code_error = result['code_error']
        duration = result['duration']
        direction = result['direction']
        typee = result['type']
        Mode_authApp_Axway = result['Mode_authApp_Axway']
        Mode_authAxway_Backend = result['Mode_authAxway_Backend']
		
		#Prepare the feature vector for prediction
        pkl_file = open('cat', 'rb')
        index_dict = pickle.load(pkl_file)
        cat_vector = np.zeros(len(index_dict))
        
        try:
            cat_vector[index_dict['méthode'+str(méthode)]] = 1
        except:
            pass
        try:
            cat_vector[index_dict['code_error'+str(code_error)]] = 1
        except:
            pass
        try:
            cat_vector[index_dict['duration'+str(duration)]] = 1
        except:
            pass
        try:
            cat_vector[index_dict['direction'+str(direction)]] = 1
        except:
            pass
        try:
            cat_vector[index_dict['type'+str(typee)]] = 1
        except:
            pass
        try:
            cat_vector[index_dict['Mode_authApp_Axway'+str(Mode_authApp_Axway)]] = 1
        except:
            pass
        try:
            cat_vector[index_dict['Mode_authApp_Axway'+str(Mode_authApp_Axway)]] = 1
        except:
            pass
        
        pkl_file = open('model_LR.pkl', 'rb')
        logmodel = pickle.load(pkl_file)
        prediction = model_LR.predict(cat_vector)
        
        return render_template('result.html',prediction=prediction)
if __name__ == "__main__" :  # ne pas exécuter dans un notebook
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2019-06-22 18:43:01,779] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-f3b6d93889cd>", line 5, in home
#     return render_template('home.html')
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: home.html
# 127.0.0.1 - - [22/Jun/2019 18:43:01] "GET / HTTP/1.1" 500 -
# [2019-06-23 03:31:36,293] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-f3b6d93889cd>", line 5, in home
#     return render_template('home.html')
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: home.html
# 127.0.0.1 - - [23/Jun/2019 03:31:36] "GET / HTTP/1.1" 500 -
# [2019-06-23 03:43:45,419] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-f3b6d93889cd>", line 5, in home
#     return render_template('home.html')
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\jinja2\loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\Abderrahmane\Anaconda3\lib\site-packages\flask\templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: home.html
# 127.0.0.1 - - [23/Jun/2019 03:43:45] "GET / HTTP/1.1" 500 -
